# %%
import os
import re
import json
import pandas as pd
from datetime import datetime
from collections import deque
import numpy as np

file_path = "../../edge/processed_topic_samples/plc_processed_cnc_tooldelay_s02.json"

# JSON 읽기
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# timestamp 변환
for obj in data:
    ts = obj.get("timestamp")
    if ts:
        obj["timestamp"] = datetime.fromisoformat(ts.replace("Z", "+00:00"))

# DataFrame 생성
df = pd.DataFrame(data)

# timestamp 없는 행 제거
df = df[df["timestamp"].notna()].copy()

# 정렬
df = df.sort_values("timestamp").reset_index(drop=True)

df.head()
# Out:
#                   timestamp   edgeId  equipmentId    jobId     productId  \
# 0 2026-03-03 08:00:09+00:00  EDGE_01       CNC_01  JOB_001  BRAKEROTER_A
# 1 2026-03-03 08:00:10+00:00  EDGE_01       CNC_01  JOB_001  BRAKEROTER_A
# 2 2026-03-03 08:00:11+00:00  EDGE_01  Conveyor_01  JOB_001  BRAKEROTER_A
# 3 2026-03-03 08:00:12+00:00  EDGE_01  Conveyor_01  JOB_001  BRAKEROTER_A
# 4 2026-03-03 08:02:40+00:00  EDGE_01       CNC_01  JOB_001  BRAKEROTER_A
#
#     lotId         eventType previousState currentState previousMode  \
# 0  LOT_01   MODE_TRANSITION           NaN          NaN        SETUP
# 1  LOT_01  STATE_TRANSITION          IDLE          RUN          NaN
# 2  LOT_01   MODE_TRANSITION           NaN          NaN        SETUP
# 3  LOT_01  STATE_TRANSITION          IDLE          RUN          NaN
# 4  LOT_01  STATE_TRANSITION           RUN     COMPLETE          NaN
#
#   currentMode  durationSec  alarmCode  deltaTotal  deltaGood  deltaReject
# 0        AUTO          NaN        NaN         NaN        NaN          NaN
# 1         NaN         10.0        NaN         NaN        NaN          NaN
# 2        AUTO          NaN        NaN         NaN        NaN          NaN
# 3         NaN         10.0        NaN         NaN        NaN          NaN
# 4         NaN        150.0        NaN         NaN        NaN          NaN

# %%
# Line_01 제품 기준 PRODUCTION_COMPLETE 이벤트만 추출
line_events = df[(df["equipmentId"] == "Line_01") 
                 & (df["eventType"] == "PRODUCTION_COMPLETE")].sort_values("timestamp").reset_index(drop=True)


# 최근 5개 제품 Window
# deque -> sliding window 구현에 편리
window = deque(maxlen=5)

# %%
features_list = []
max_window_size = 5

for idx, event in line_events.iterrows():
    # window 에 이벤트 추가
    window.append(event)

    
    if len(window) == 5:
        # Feature 계산
        # 1) 생산 속도 Feature (평균 interval, std)
        timestamps = [e["timestamp"] for e in window]
        if len(timestamps) > 1:
            intervals = [(timestamps[i] - timestamps[i-1]).total_seconds() for i in range(1, len(timestamps))]
            production_interval_avg = np.mean(intervals)
            production_interval_std = np.std(intervals)
        else:
            production_interval_avg = None
            production_interval_std = None
        

        # 2) 설비 사이클 Feature (CNC RUN -> COMPLETE 기준)
        cycle_events = df[
            (df["equipmentId"] == "CNC_01") &
            (df["eventType"] == "STATE_TRANSITION") &
            (df["previousState"] == "RUN") &
            (df["currentState"] == 'COMPLETE')
        ]
        # window에 해당하는 cycle_events 선택
        cycle_times = []
        for w in window:
            matches = cycle_events[
                (cycle_events["timestamp"] >= w["timestamp"] - pd.Timedelta(seconds=300))&
                (cycle_events["timestamp"] <= w["timestamp"])
            ]
            cycle_times.extend([c["durationSec"] for _, c in matches.iterrows() if c["durationSec"]])
        if cycle_times:
            cycle_time_avg = np.mean(cycle_times)
            cycle_time_std = np.std(cycle_times)
        else:
            cycle_time_avg = None
            cycle_time_std = None


        # 3) 알람 Feature
        alarm_events = df[
            (df["eventType"] == "ALARM_ON") &
            (df["timestamp"] <= event["timestamp"])
        ]
        alarm_count = len(alarm_events)
        alarm_rate = alarm_count / len(window)

        # 4) 설비 상태 Feature (HOLD/IDLE)
        hold_count = len(df[(df["eventType"] == "STATE_TRANSITION") & (df["currentState"]=="HOLD") & 
                            (df["timestamp"] <= event["timestamp"])])
        idle_count = len(df[(df["eventType"] == "STATE_TRANSITION") & (df["currentState"]=="IDLE") &
                            (df["timestamp"] <= event["timestamp"])])
        
        
        # 5) 작업자 개입 Feature (AUTO -> MANUAL)
        manual_mode_count = len(df[(df["eventType"] == "MODE_TRANSITION") &
                                   (df["previousMode"]=="AUTO") &
                                   (df["currentMode"]=="MANUAL") &
                                   (df["timestamp"] <= event["timestamp"])])
        

        # 6) 품질 Feature
        good_count = sum(1 for w in window if w["deltaGood"] is not None and w["deltaGood"] >0)
        reject_count = sum(1 for w in window if w["deltaReject"] is not None and w["deltaReject"] >0)
        reject_rate = reject_count / len(window)


        # 연속 불량 계산
        reject_streak = 0
        current_streak = 0
        for w in window:
            if w["deltaReject"] is not None and w["deltaReject"] >0:
                current_streak += 1
                reject_streak = max(reject_streak, current_streak)
            else:
                current_streak = 0
        
        feature_record = {
            "timestamp" : event["timestamp"].isoformat(),
            "production_interval_avg": production_interval_avg,
            "production_interval_std": production_interval_std,
            "cycle_time_avg": cycle_time_avg,
            "cycle_time_std": cycle_time_std,
            "alarm_count": alarm_count,
            "alarm_rate": float(alarm_rate),
            "hold_count": hold_count,
            "idle_count": idle_count,
            "manual_mode_count": manual_mode_count,
            "good_count": good_count,
            "reject_count": reject_count,
            "reject_rate": reject_rate,
            "reject_streak": reject_streak
        }
        features_list.append(feature_record)
print(features_list)
# Out:
# [{'timestamp': '2026-03-03T08:14:50+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 5, 'reject_count': 0, 'reject_rate': 0.0, 'reject_streak': 0}, {'timestamp': '2026-03-03T08:17:30+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 4, 'reject_count': 1, 'reject_rate': 0.2, 'reject_streak': 1}, {'timestamp': '2026-03-03T08:20:10+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 4, 'reject_count': 1, 'reject_rate': 0.2, 'reject_streak': 1}, {'timestamp': '2026-03-03T08:22:50+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 3, 'reject_count': 2, 'reject_rate': 0.4, 'reject_streak': 1}, {'timestamp': '2026-03-03T08:25:30+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 2, 'reject_count': 3, 'reject_rate': 0.6, 'reject_streak': 2}, {'timestamp': '2026-03-03T08:28:10+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 0, 'idle_count': 0, 'manual_mode_count': 0, 'good_count': 1, 'reject_count': 4, 'reject_rate': 0.8, 'reject_streak': 3}, {'timestamp': '2026-03-03T08:30:50+00:00', 'production_interval_avg': np.float64(160.0), 'production_interval_std': np.float64(0.0), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 1, 'idle_count': 0, 'manual_mode_count': 1, 'good_count': 1, 'reject_count': 4, 'reject_rate': 0.8, 'reject_streak': 4}, {'timestamp': '2026-03-03T08:36:40+00:00', 'production_interval_avg': np.float64(207.5), 'production_interval_std': np.float64(82.27241335952168), 'cycle_time_avg': np.float64(150.0), 'cycle_time_std': np.float64(0.0), 'alarm_count': 1, 'alarm_rate': 0.2, 'hold_count': 1, 'idle_count': 2, 'manual_mode_count': 1, 'good_count': 1, 'reject_count': 4, 'reject_rate': 0.8, 'reject_streak': 4}]

# %%
import json

# JSON 파일로 저장
with open("../../kafka_streams/feature_topic_samples/feature_tooldelay_s02.json","w") as f:
    json.dump(features_list, f, ensure_ascii=False, indent=4)


# DataFrame 으로 변환 -> csv로 저장
feature_df = pd.DataFrame(features_list)
feature_df.to_csv("../../kafka_streams/feature_topic_samples/feature_tooldelay_s02.csv", index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 예시 feature_df: timestamp, good_count, reject_count, alarm_count
feature_df["total_delta"] = feature_df["good_count"] + feature_df["reject_count"]
feature_df["reject_rate_calc"] = feature_df["reject_count"] / feature_df["total_delta"]
feature_df.loc[feature_df["total_delta"] == 0, "reject_rate_calc"] = None  # 생산 0 제외

plt.figure(figsize=(12,4))
plt.plot(feature_df["timestamp"], feature_df["reject_rate_calc"], label="Reject Rate", marker='o')

# 알람 발생 시점 표시
alarm_times = feature_df.loc[feature_df["alarm_count"] > 0, "timestamp"]
alarm_values = feature_df.loc[feature_df["alarm_count"] > 0, "reject_rate_calc"]
plt.scatter(alarm_times, alarm_values, color='red', label="Alarm", zorder=5)

plt.xticks(rotation=45)
plt.ylabel("Reject Rate")
plt.xlabel("Timestamp")
plt.title("Reject Rate Over Time with Alarm Occurrences")
plt.legend()
plt.show()

# %%
# =========================
# Feature Evolution Before Visible Failure
# Portfolio Final Version (Layout Fixed)
# =========================

import matplotlib.pyplot as plt
import pandas as pd

# feature_topic 결과 DataFrame 사용
plot_df = feature_df.copy()

# timestamp 정리
plot_df["timestamp"] = pd.to_datetime(plot_df["timestamp"])
plot_df["timestamp_str"] = plot_df["timestamp"].dt.strftime("%H:%M")
plot_df = plot_df.sort_values("timestamp").reset_index(drop=True)

# 필요한 컬럼 확인
required_cols = [
    "timestamp",
    "production_interval_std",
    "reject_rate",
    "reject_streak",
    "reject_count"
]
missing_cols = [c for c in required_cols if c not in plot_df.columns]
if missing_cols:
    raise ValueError(f"필요한 컬럼이 없습니다: {missing_cols}")

# reject 시작 시점 찾기
reject_rows = plot_df[plot_df["reject_count"] > 0]
reject_start_idx = reject_rows.index.min() if not reject_rows.empty else None

# 정규화용 최대값
interval_max = plot_df["production_interval_std"].max()
if interval_max == 0:
    interval_max = 1

streak_max = plot_df["reject_streak"].max()
if streak_max == 0:
    streak_max = 1

# 정규화
plot_df["interval_std_norm"] = plot_df["production_interval_std"] / interval_max
plot_df["reject_streak_norm"] = plot_df["reject_streak"] / streak_max

# 그래프 시작
plt.figure(figsize=(11, 5))

# 시계열 그래프
plt.plot(
    plot_df["timestamp_str"],
    plot_df["interval_std_norm"],
    marker="o",
    label="Production Variability"
)
plt.plot(
    plot_df["timestamp_str"],
    plot_df["reject_rate"],
    marker="o",
    label="Reject Rate"
)
plt.plot(
    plot_df["timestamp_str"],
    plot_df["reject_streak_norm"],
    marker="o",
    label="Reject Streak"
)

# reject 시작 시점 강조
if reject_start_idx is not None:
    reject_time = plot_df.loc[reject_start_idx, "timestamp_str"]
    plt.axvline(reject_time, linestyle="--", linewidth=1.2)


# 스타일
plt.legend(loc="lower right")
plt.xticks(rotation=45)
plt.ylim(0, 1.05)
plt.tight_layout()
plt.show()
